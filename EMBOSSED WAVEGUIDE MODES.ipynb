# %%
import sympy as sp
import math
from sympy import Symbol
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from scipy import sparse
import sys
import matplotlib
from matplotlib.ticker import MaxNLocator
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from numpy.random import randn, shuffle
from scipy import linspace, meshgrid, arange, empty, concatenate, newaxis, shape
x=Symbol('x')
#l=float(input("Enter wavelength of incident wave:"))
l=1.5
k0=2*3.14/l
def K(n):                  # wave number
    y=k0*(n**2-x**2)**0.5
    return y
print(K(1))
#layers=int(input("Enter no. of layers in waveguide:"))
#waveguides=int(input("Enter no. of parllel waveguides:"))
layers=3
waveguides=1
ref=[1.48,1.5,1.48]
width=[10,5.912,10]
a=[]
b=[]
Z=[]
#for i in range(layers):
    #ref=ref+[float(input("Refractive index:n"+str(i)+"="))]
    #width=width+[float(input("Width for n"+str(i)+"="))]
for j in range(layers-1):
    matrix1=sp.Matrix([[1,0],[0,1]])
    
    for i in range(j,layers-1):
        n1=ref[i]
        n2=ref[i+1]
        d=width[i]

        S=(K(n2)/K(n1))
        L1=(sp.exp(-1j*K(n1)*d))
        L2=sp.exp(1j*K(n1)*d)
        ele11=(0.5*(1+S)*L1)
        ele12=(0.5*(1-S)*L1)
        ele21=(0.5*(1-S)*L2)
        ele22=(0.5*(1+S)*L2)
        matrix2=sp.Matrix([[ele11,ele12],[ele21,ele22]])
        matrix=matrix1*(matrix2)
        matrix1=(matrix)
    a0=matrix[0]
    b0=matrix[2]
    equ=matrix[0]
    a=a+[a0]
    b=b+[b0]
    if j==0:
          equa=(equ)
def fun(y):
    return ((equa.subs(x,y)))
y12=np.arange(ref[2]+((ref[1]-ref[2])/100),ref[1],(ref[1]-ref[2])/100)
z1=[]

for i in y12:
    z1=z1+[sp.re(sp.N(fun(i)))]
for j in range(0,len(y12)-1):
    if (z1[j]*z1[j+1]<0):
        y1=y12[j]
        y2=y12[j+1]

        y3=(y1+y2)/2
        E=(sp.re(sp.N(fun(y3))))
        D=(sp.re(sp.N(fun(y1))))
        while abs(E)>0.001:
            if ((D*E)<=0):
                y2=y3
            else:
                 y1=y3
            y3=(y1+y2)/2
            E=(sp.re(sp.N(fun(y3))))
    
        Z=Z+[y3]   
print(Z)
A=[]
B=[]
for k in range(len(Z)):
    A1=[]
    B1=[]
    for i in range(layers-1):
   
         sp.sigmoid=(a[i])
         VA=sp.N(sp.sigmoid.subs(x,Z[k]))
         sp.sigmoid=(b[i])
         VB=sp.N(sp.sigmoid.subs(x,Z[k]))
         
         A1=A1+[VA]
         B1=B1+[VB]
        
    A1=A1+[1]
    B1=B1+[0]
    A=A+[A1]
    B=B+[B1]
N2=[]
for k in range(len(Z)):
    d=0
    m=[]
    z=[]
    for j in range(layers):
        y=np.arange(d,d+width[j]+0.01,0.01)
        for i in  y:
            m=m+[i]
            sp.sigmoid=(A[k][j]*sp.exp(1j*K(ref[j])*(i-d))+B[k][j]*sp.exp(-1j*K(ref[j])*(i-d)))
            z=z+[sp.re(sp.N(sp.sigmoid.subs(x,Z[k])))]
        d = d + width[j]

    N2=N2+[z]
#     plt.plot(m,z)
#     plt.xlabel('X')
#     plt.grid()
#     plt.show()
plt.plot(m,N2[1])
plt.xlabel('X')
plt.grid()
plt.show()
# Out:
# 4.18666666666667*(1 - x**2)**0.5
# [1.488600195312499, 1.4970059577941872]

# %%
import sympy as sp
import math
from sympy import Symbol
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from scipy import sparse
import sys
import matplotlib
from matplotlib.ticker import MaxNLocator
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from numpy.random import randn, shuffle
from scipy import linspace, meshgrid, arange, empty, concatenate, newaxis, shape
x=Symbol('x')
#l=float(input("Enter wavelength of incident wave:"))
l=1.5
k0=2*3.14/l
def K(n):                  # wave number
    y=k0*(n**2-x**2)**0.5
    return y
print(K(1))
#layers=int(input("Enter no. of layers in waveguide:"))
#waveguides=int(input("Enter no. of parllel waveguides:"))
layers=3
waveguides=1
ref=[1.49,1.5,1.48]
width=[10,5.912,10]
a=[]
b=[]
Z=[]
#for i in range(layers):
    #ref=ref+[float(input("Refractive index:n"+str(i)+"="))]
    #width=width+[float(input("Width for n"+str(i)+"="))]
for j in range(layers-1):
    matrix1=sp.Matrix([[1,0],[0,1]])
    
    for i in range(j,layers-1):
        n1=ref[i]
        n2=ref[i+1]
        d=width[i]

        S=(K(n2)/K(n1))
        L1=(sp.exp(-1j*K(n1)*d))
        L2=sp.exp(1j*K(n1)*d)
        ele11=(0.5*(1+S)*L1)
        ele12=(0.5*(1-S)*L1)
        ele21=(0.5*(1-S)*L2)
        ele22=(0.5*(1+S)*L2)
        matrix2=sp.Matrix([[ele11,ele12],[ele21,ele22]])
        matrix=matrix1*(matrix2)
        matrix1=(matrix)
    a0=matrix[0]
    b0=matrix[2]
    equ=matrix[0]
    a=a+[a0]
    b=b+[b0]
    if j==0:
          equa=(equ)
def fun(y):
    return ((equa.subs(x,y)))
y12=np.arange(ref[2],ref[1],(ref[1]-ref[2])/100)
z1=[]

for i in y12:
    z1=z1+[sp.re(sp.N(fun(i)))]
for j in range(0,len(y12)-1):
    if (z1[j]*z1[j+1]<0):
        y1=y12[j]
        y2=y12[j+1]

        y3=(y1+y2)/2
        E=(sp.re(sp.N(fun(y3))))
        D=(sp.re(sp.N(fun(y1))))
        while abs(E)>0.001:
            if ((D*E)<=0):
                y2=y3
            else:
                 y1=y3
            y3=(y1+y2)/2
            E=(sp.re(sp.N(fun(y3))))
    
        Z=Z+[y3]   
print(Z)
A=[]
B=[]
for k in range(len(Z)):
    A1=[]
    B1=[]
    for i in range(layers-1):
   
         sp.sigmoid=(a[i])
         VA=sp.N(sp.sigmoid.subs(x,Z[k]))
         sp.sigmoid=(b[i])
         VB=sp.N(sp.sigmoid.subs(x,Z[k]))
         
         A1=A1+[VA]
         B1=B1+[VB]
        
    A1=A1+[1]
    B1=B1+[0]
    A=A+[A1]
    B=B+[B1]
N1=[]
for k in range(len(Z)):
    d=0
    m=[]
    z=[]
    for j in range(layers):
        y=np.arange(d,d+width[j]+0.01,0.01)
        for i in  y:
            m=m+[i]
            sp.sigmoid=(A[k][j]*sp.exp(1j*K(ref[j])*(i-d))+B[k][j]*sp.exp(-1j*K(ref[j])*(i-d)))
            z=z+[sp.re(sp.N(sp.sigmoid.subs(x,Z[k])))]
        d = d + width[j]

    N1=N1+[z]
#     plt.plot(m,z)
#     plt.xlabel('X')
#     plt.grid()
#     plt.show()
plt.plot(m,N1[3])
plt.xlabel('X')
plt.grid()
plt.show()
# Out:
# 4.18666666666667*(1 - x**2)**0.5
# [1.4831093749999997, 1.4877171874999995, 1.4904929687499988, 1.49731598510742]

# %% [markdown]
# # TE_01

# %%
def Z(x,y):
    return np.multiply.outer(N2[1],N1[2])
# np.shape(Z(x,y))

# %%
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-10, 10, 2596)
y = np.linspace(-10, 10, 2596)
Z =Z(x,y)
M, N = np.meshgrid(x, y)

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(121, projection='3d')
ax.plot_surface(M, N, Z, cmap = plt.cm.jet)
ax.set_xlabel('$X$')
ax.set_ylabel('$Y$')
ax.set_zlabel('$Z$')
plt.title("Side View")
for angle in range(0, 360):
    ax.view_init(0, angle)
ax = fig.add_subplot(122, projection='3d')
ax.plot_surface(M, N, Z, cmap = plt.cm.jet)
ax.set_xlabel('$X$')
ax.set_ylabel('$Y$')
ax.set_zlabel('$Z$')
plt.title("Top View")
for angle in range(0, 360):
    ax.view_init(90, angle)
plt.show()

# %% [markdown]
# # TE_00

# %%
def Z1(x,y):
    return np.multiply.outer(N2[1],N1[3])
# np.shape(Z(x,y))

# %%
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-10, 10, 2596)
y = np.linspace(-10, 10, 2596)
Z =Z1(x,y)
M, N = np.meshgrid(x, y)

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(121, projection='3d')
ax.plot_surface(M, N, Z, cmap = plt.cm.jet)
ax.set_xlabel('$X$')
ax.set_ylabel('$Y$')
ax.set_zlabel('$Z$')
plt.title("Side View")
for angle in range(0, 360):
    ax.view_init(0, angle)
ax = fig.add_subplot(122, projection='3d')
ax.plot_surface(M, N, Z, cmap = plt.cm.jet)
ax.set_xlabel('$X$')
ax.set_ylabel('$Y$')
ax.set_zlabel('$Z$')
plt.title("Top View")
for angle in range(0, 360):
    ax.view_init(90, angle)
plt.show()

# %% [markdown]
# # TE_11

# %%
def Z2(x,y):
    return np.multiply.outer(N2[0],N1[2])
# np.shape(Z(x,y))

# %%
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-10, 10, 2596)
y = np.linspace(-10, 10, 2596)
Z =Z2(x,y)
M, N = np.meshgrid(x, y)

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(121, projection='3d')
ax.plot_surface(M, N, Z, cmap = plt.cm.jet)
ax.set_xlabel('$X$')
ax.set_ylabel('$Y$')
ax.set_zlabel('$Z$')
plt.title("Side View")
for angle in range(0, 360):
    ax.view_init(0, angle)
ax = fig.add_subplot(122, projection='3d')
ax.plot_surface(M, N, Z, cmap = plt.cm.jet)
ax.set_xlabel('$X$')
ax.set_ylabel('$Y$')
ax.set_zlabel('$Z$')
plt.title("Top View")
for angle in range(0, 360):
    ax.view_init(90, angle)
plt.show()
